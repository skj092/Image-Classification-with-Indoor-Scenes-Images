# %%
# !pip install --upgrade fastai

# %%
from fastai.vision.all import *

# %%
dataset_url = "https://storage.googleapis.com/kaggle-data-sets/358221/702372/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210925%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210925T023423Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

# %%
path = untar_data(url=dataset_url)
path = Path(path/'indoorCVPR_09/Images')
Path.BASE_PATH = path
path.ls()

# %%
dblock = DataBlock(blocks=(ImageBlock, CategoryBlock),
                  get_items=get_image_files,
                  get_y = parent_label,
                  splitter=RandomSplitter(),
                  item_tfms = Resize(224))

# %%
dls = dblock.dataloaders(path)

# %%
dls.show_batch()

# %%
learn = cnn_learner(dls, resnet18, metrics=accuracy)
learn.fine_tune(2)
